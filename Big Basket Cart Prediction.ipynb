# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_excel('Big_Basket.xlsx', header=None)

# %%
data = data.iloc[1:]
data
# Out:
#                  0                    1         2             3   \
# 1           chutney                  NaN       NaN           NaN
# 2              knor  ginger garlic paste  MTR Idli           NaN
# 3            turkey          spirit fish  tomatoes     spaghetti
# 4              eggs                  NaN       NaN           NaN
# 5            kinley                  NaN       NaN           NaN
# ...             ...                  ...       ...           ...
# 7215  mineral water            green tea       NaN           NaN
# 7216      green tea                  NaN       NaN           NaN
# 7217  patanjali tea              chicken      eggs  french fries
# 7218  mineral water                 milk      cake      brownies
# 7219       neckrest         french fries       NaN           NaN
#
#                  4              5       6     7        8   \
# 1               NaN            NaN     NaN   NaN      NaN
# 2               NaN            NaN     NaN   NaN      NaN
# ...

# %%
len(data)
# Out:
# 7219

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.values.tolist()[0:3]
# Out:
# [['chutney',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['knor',
#   'ginger garlic paste',
#   'MTR Idli',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['turkey',
#   'spirit fish',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'patanjali tea',
#   'salmon',
#   'eggs',
#   'chicken',
#   'cadbury white chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan]]

# %%
final_product_list = []

for i in data.values.tolist():
    product_list = []
#     print(i)
    for j in i:
        if not pd.isnull(j):
            product_list.append(j)
    
    final_product_list.append(product_list)

# %%
final_product_list
# Out:
# [['chutney'],
#  ['knor', 'ginger garlic paste', 'MTR Idli'],
#  ['turkey',
#   'spirit fish',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'patanjali tea',
#   'salmon',
#   'eggs',
#   'chicken',
#   'cadbury white chocolate'],
#  ['eggs'],
#  ['kinley'],
#  ['mineral water', 'eggs', 'chicken', 'chocolate', 'french fries'],
#  ['vegetable basket', 'spaghetti', 'yams', 'mineral water'],
#  ['spaghetti', 'muffins'],
#  ['parle g'],
#  ['knor', 'eggs'],
#  ['wholed cheeze', 'paneer', 'spaghetti', 'mineral water', 'white wine'],
#  ['parle g'],
#  ['maggi', 'pasta', 'mineral water', 'eggs'],
#  ['pasta'],
#  ['chocolate', 'milk'],
#  ['turkey', 'eggs', 'chocolate', 'frooti', 'tomato juice'],
#  ['parle g'],
#  ['basmati rice'],
#  ['maggi', 'pasta', 'yams', 'milk', 'chocolate'],
#  ['muffins'],
#  ['whole wheat pasta',
#   'paneer',
#   'spaghetti',
#   'knor',
#   'meatballs',
#   'chicken',
#   'condoms',
#   'cooking oil',
#   'sulaa vines',
#   'yogurt cake',
# ...

# %%
len(final_product_list)
# Out:
# 7219

# %% [markdown]
# ## Apriori Training on DataSet

# %%
from apyori import apriori

# %% [markdown]
# ## Raw Results

# %%
basket_intelligence = apriori(transactions=final_product_list, min_support=0.002, min_confidence=0.2, min_lift=3, min_length=2)

# %%
results = list(basket_intelligence)
results
# Out:
# [RelationRecord(items=frozenset({'5 star', 'pancakes'}), support=0.0022163734589278295, ordered_statistics=[OrderedStatistic(items_base=frozenset({'5 star'}), items_add=frozenset({'pancakes'}), confidence=0.326530612244898, lift=3.446234634204559)]),
#  RelationRecord(items=frozenset({'MTR Idli', 'parle g'}), support=0.00207785011774484, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MTR Idli'}), items_add=frozenset({'parle g'}), confidence=0.2631578947368421, lift=3.247413405308142)]),
#  RelationRecord(items=frozenset({'burgers', 'almonds'}), support=0.005402410306136584, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'burgers'}), confidence=0.26530612244897955, lift=3.0594966421073218)]),
# ...

# %%
def inspect (results1) :
    product1 = [tuple (result [2][0][0])[0] for result in results]
    product2 = [tuple (result [2][0][1])[0] for result in results]
    supports = [result[1] for result in results]
    confidences = [result [2][0][2] for result in results]
    lifts = [result[2][0][3] for result in results]
    return list(zip(product1, product2, supports, confidences, lifts) )
DataFrame_intelligence = pd. DataFrame (inspect(results), columns = ['product1', 'product2', 'Support', 'Confidence', 'Lift'])

# %%
DataFrame_intelligence.nlargest(n=10, columns=['Lift'])
# Out:
#           product1          product2   Support  Confidence       Lift
# 131          pasta      pepper spray  0.002493    0.461538  23.970116
# 243       tomatoes         spaghetti  0.002216    0.307692  10.888386
# 244           milk     mineral water  0.002078    0.326087   9.019240
# 215          maggi         spaghetti  0.002493    0.219512   7.767934
# 163      olive oil              milk  0.002078    0.277778   7.653732
# 87    fruit basket  vegetable basket  0.002216    0.666667   6.985002
# 148      chocolate     mineral water  0.002355    0.257576   6.260739
# 128  mineral water         olive oil  0.003602    0.382353   5.823219
# 20            buns            paneer  0.002355    0.566667   5.745459
# 207           knor     mineral water  0.003186    0.207207   5.731145
